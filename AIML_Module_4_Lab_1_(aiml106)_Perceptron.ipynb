# %% [markdown]
# <a href="https://colab.research.google.com/github/Manoj-Kumar22/IIITH_Aiml_Labwork/blob/main/AIML_Module_4_Lab_1_(aiml106)_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 4: Perceptron and Gradient Descent
# ## Lab 1: Perceptron
#
# In this lab, we will be studying the perceptron learning algorithm.

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# First we need to define a labeled data set. Let's make a toy dataset.

# %%
X = np.array([
    [-2, 4],
    [4, 1],
    [1, 6],
    [2, 4],
    [6, 2]
])

# %% [markdown]
# Next we need to add a bias term -1 into the data set.

# %%
X = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])

# %%
y = np.array([-1, -1, 1, 1, 1])

# %% [markdown]
# This small toy data set contains two samples labeled with −1 and three samples labeled with +1. This means we have a binary classification problem, as the data set contains two sample classes. Lets plot the dataset to see, that is is linearly seperable

# %%
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Print a possible hyperplane, that is seperating the two classes.
plt.plot([-2, 6], [6, 0.5])

# %% [markdown]
# Finally we can code our Perceptron algorithm using our update rule. To keep it simple, we will linearly loop over the sample set. For larger data sets it makes sence, to randomly pick a sample during each iteration in the for-loop.
#
# ![image.png](data:image/png;base64,...)
#
# The algorithm is shown in the above image.

# %%
def perceptron_algo(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 10

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

# %%
def perceptron_algo_plot(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %% [markdown]
# Next, we will see the the training error at each epoch.

# %%
w = perceptron_algo_plot(X, y)

# %% [markdown]
# We now plot the decision boundary and check which samples have been classified as positive and which samples have been classified as negative.

# %%
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Add our test samples

plt.scatter(2, 2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4, 3, s=120, marker='+', linewidths=2, color='blue')

# Print the hyperplane calculated by perceptron_sgd()
x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %% [markdown]
# As you can see, our algorithm has correctly classified all the samples. The decision boundary is shown in blue.

# %% [markdown]
# # Things to try
#
#
# 1.   Try this on a real dataset like the Sonar dataset or the Banknote Dataset and show the error plot.
# 2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
# 4. Take a toy dataset that is not linearly separable and run the perceptron algorithm on it. What happens? Note your observations. An example is given below.

# %% [markdown]
# 1.**Sonar** **Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8982275f-c47c-44ab-88b3-675221ea2ce2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8982275f-c47c-44ab-88b3-675221ea2ce2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dd=pd.read_csv('BankNote_Authentication.csv')
dd
# Out:
#       variance  skewness  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
#1Try this on a real dataset like the Sonar dataset or the Banknote Dataset and show the error plot.
dd.columns = ['A', 'B', 'C', 'D', 'E']
X = dd[['A', 'B', 'C', 'D']].values
y = dd['E'].values
X = np.column_stack((X, np.ones(len(X))))
w = perceptron_algo_plot(X, y)
for i in range(len(X)):
    plt.scatter(X[i, 0], X[i, 1], s=120, marker='_' if y[i] == 0 else '+', linewidths=2)
x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]
x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')
plt.show()

# %%
#2Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
def perceptron_algo_plot(X, Y, eta=1.0):
    w = np.zeros(X.shape[1])
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

dd.columns = ['A', 'B', 'C', 'D', 'E']
X = dd[['A', 'B', 'C', 'D']].values
y = dd['E'].values
X = np.column_stack((X, np.ones(len(X))))
X[:, :2] += np.random.normal(0, 0.2, size=X[:, :2].shape)

learning_rates = [0.01, 0.1, 1.0, 10.0]

plt.figure(figsize=(12, 8))
for lr in learning_rates:
    X_copy = X.copy()
    w = perceptron_algo_plot(X_copy, y, eta=lr)

    plt.scatter(X_copy[:, 0], X_copy[:, 1], c=y, cmap='viridis', s=50, edgecolors='k', linewidths=1, label=f'LR={lr}')

    x2 = [w[0], w[1], -w[1], w[0]]
    x3 = [w[0], w[1], w[1], -w[0]]
    x2x3 = np.array([x2, x3])
    X_, Y, U, V = zip(*x2x3)
    ax = plt.gca()
    ax.quiver(X_, Y, U, V, scale=1)

plt.xlabel('Feature A')
plt.ylabel('Feature B')
plt.legend()
plt.title('Learning Rate on Perceptron Convergence')
plt.show()

# %%
# 3.Take a toy dataset that is not linearly separable and run the perceptron algorithm on it. What happens? Note your observations. An example is given below.

import numpy as np
import matplotlib.pyplot as plt

X_non_linear = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])
y_non_linear = np.array([-1, -1, 1, -1, -1])

for d, sample in enumerate(X_non_linear):
    plt.scatter(sample[0], sample[1], s=120, marker='_' if y_non_linear[d] == -1 else '+', linewidths=2)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Non-linearly Separable Toy Dataset')
plt.show()

def perceptron_algo_non_linear(X, Y):
    w = np.zeros(len(X[0]))
    eta = 0.1
    epochs = 100

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]

    return w

w_non_linear = perceptron_algo_non_linear(X_non_linear, y_non_linear)

for d, sample in enumerate(X_non_linear):
    plt.scatter(sample[0], sample[1], s=120, marker='_' if y_non_linear[d] == -1 else '+', linewidths=2)

if w_non_linear is not None:
    x2 = [w_non_linear[0], w_non_linear[1], -w_non_linear[1], w_non_linear[0]]
    x3 = [w_non_linear[0], w_non_linear[1], w_non_linear[1], -w_non_linear[0]]
    x2x3 = np.array([x2, x3])
    X, Y, U, V = zip(*x2x3)
    ax = plt.gca()
    ax.quiver(X, Y, U, V, scale=1)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Perceptron on Non-linearly Separable Toy Dataset')
plt.show()

# %%
X = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])

# %%
y = np.array([-1, -1, 1, -1, -1])

# %%
print(perceptron_algo_plot(X, y))
# Out:
# [-2.  3. 15.]

# %% [markdown]
# If the training data is not Linearly Separable, the perceptron algorithm will eventually repeat the same set of weights and thereby enter an infinite loop.
